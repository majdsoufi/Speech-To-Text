# %%
import scipy
import matplotlib.pyplot as plt 
import pandas as pd
signal = pd.read_csv('signaljour1.txt' , header=None , sep = ',')
signal.head()

signal.shape
signal = signal.iloc[:,0:8]
signal.head()


import numpy as np
import seaborn as sns

sns.set_style("darkgrid" )
plt.plot(signal )
plt.show()


FrequenceFondamentale = 1/10
print("La Fréquence Fondamentale est de ",FrequenceFondamentale)
print('La longueur donde est de  =  10 ')


sig1 = signal.iloc[:,0]
sig2 = signal.iloc[:,1]
sig3 = signal.iloc[:,2]
sig4 = signal.iloc[:,3]
sig5 = signal.iloc[:,4]


sum1 = sig1 * sig2 * sig3 * sig4 *  sig5
plt.plot(sum1)
plt.show()


sum2 = sig1 + sig2 + sig3 + sig4 +  sig5
plt.plot(sum2)
plt.show()

sum2 = 0.5*(sig1 + sig2) + (sig3*sig4)*0.33 +  0.125*sig5
plt.plot(sum2)
plt.show()


sig7 = signal.iloc[:,4]
plt.plot(sig7)
plt.show()

from scipy import fft
from scipy import ifft

import numpy
x = np.ravel(signal)
x.shape


plt.plot(x)
plt.show()


from scipy import fftpack
from matplotlib import pyplot as plt
import numpy as np
from scipy import fftpack

plt.plot(x)



f_s =48000

X = fftpack.fft(x)
freqs = fftpack.fftfreq(len(x)) * f_s

fig, ax = plt.subplots()

ax.stem(freqs, np.abs(X))
ax.set_xlabel('Frequency in Hertz [Hz]')
ax.set_ylabel('Frequency Domain (Spectrum) Magnitude')
ax.set_xlim(0, f_s / 2)
ax.set_ylim(-5, 110)

plt.show()

# %%
#import signaljour1.py as sig

# %%
import numpy as np

# %%
S_rate = 48000
T = 1/S_rate
t = 2
N = S_rate * t

# %%
freq = 23
omega = 2*np.pi*freq

# %%
t_seq = np.arange(N)*T

# %%
y = 0.5 * np.sin(omega*t_seq)

# %%
plt.plot(t_seq,y)
plt.show()

# %%
import pyaudio

# %%
p = pyaudio.PyAudio()

# %%
stream = p.open(format=pyaudio.paFloat32,
                channels=1,
                rate=48000,
                output=True)

# %%
stream.write(t_seq)

# %%
c = np.arange(-12, 12, 0.5)

# %%
s = 0.21 - 0.16528559 + np.sin(c)/c
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
s
# Out:
# array([ 1.66630404e-10, -3.14118661e-02, -4.61937906e-02, -3.90661386e-02,
#        -9.68770109e-03,  3.68037657e-02,  9.05053528e-02,  1.38654070e-01,
#         1.68384191e-01,  1.69781074e-01,  1.38569638e-01,  7.78097928e-02,
#        -1.85483970e-03, -8.35656492e-02, -1.47070445e-01, -1.72514505e-01,
#        -1.44486214e-01, -5.55093693e-02,  9.17544127e-02,  2.84103268e-01,
#         4.99363123e-01,  7.09711068e-01,  8.86185395e-01,  1.00356549e+00,
#                    nan,  1.00356549e+00,  8.86185395e-01,  7.09711068e-01,
#         4.99363123e-01,  2.84103268e-01,  9.17544127e-02, -5.55093693e-02,
#        -1.44486214e-01, -1.72514505e-01, -1.47070445e-01, -8.35656492e-02,
#        -1.85483970e-03,  7.78097928e-02,  1.38569638e-01,  1.69781074e-01,
#         1.68384191e-01,  1.38654070e-01,  9.05053528e-02,  3.68037657e-02,
#        -9.68770109e-03, -3.90661386e-02, -4.61937906e-02, -3.14118661e-02])

# %%
plt.plot(s)
plt.show()

# %%
import pylab
import matplotlib.pyplot as plt
a = [pow(10, i) for i in range(10)]
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

line, = ax.plot(a, color='blue', lw=2)
pylab.show()

# %%
y = np.convolve(c,x/150)

# %%
plt.figure(figsize=(15,3))
plt.plot(y)
plt.show()

# %%
stream.write(y)

# %%
base =

# %%
y = 0.5 * np.sin(x)

# %%
plt.plot(y)
plt.show()

# %%
S_rate = 45000
T = 1/S_rate
t = 0.2
N = S_rate * t

freq = 100
omega = 2*np.pi*freq


t_seq = np.arange(N)*T
b = 0.5 * np.sin(omega*t_seq)

plt.plot(b)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
S_rate = 45000
T = 1/S_rate
t = 0.2
N = S_rate * t

freq = 50
omega = 2*np.pi*freq


t_seq = np.arange(N)*T
v = 0.5 * np.sin(omega*t_seq)

# %%
plt.plot(v)
plt.show()

# %%
s = b+v
plt.plot(s)
plt.show()

# %%
S_rate = 45000
T = 1/S_rate
t = 0.2
N = S_rate * t

freq = 120
omega = 2*np.pi*freq


t_seq = np.arange(N)*T
n = 0.5 * np.sin(omega*t_seq)

plt.plot(n)
plt.show()

# %%
s = b+v + n
plt.legend('non filtered')
plt.plot(s)

plt.show()

# %%
stream.write(s)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

fs = 48000  

fc = 80  # Cut-off frequency of the filter
w = fc / (fs / 2) # Normalize the frequency
b, a = signal.butter(7, w, 'low')
output = signal.filtfilt(b, a, s)
#plt.plot(n , label=' Non filtered')
plt.plot(t_seq, output, label='filtered')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

fs = 48000  

fc = 110  # Cut-off frequency of the filter
w = fc / (fs / 2) # Normalize the frequency
b, a = signal.butter(3, w, 'high')
output = signal.filtfilt(b, a, s)
#plt.plot(n , label=' Non filtered')
plt.plot(t_seq, output, label='filtered')
plt.legend()
plt.figure(figsize=(100,155))
plt.show()
